# %%
import pandas as pd
from faker import Faker
Faker.seed(999)
import random

# %%
# Initialize Faker
fake = Faker('en_GB')

# Define the number of rows you want to generate
num_rows = 1000

# Define the columns
columns = [
    "Engagement ID",
    "Creation Date",
    "Release Date",
    "Last Time Charged Date",
    "Last Expenses Charged Date",
    "Last Active ETC-P Date",
    "Engagement",
    "Client",
    "Engagement Partner",
    "Engagement Partner GUI",
    "Engagement Manager",
    "Engagement Manager GUI",
    "Engagement Partner Service Line",
    "Engagement Status",
]

# %%
# Create a list to hold the data
data = []

# Generate dummy data
for _ in range(num_rows):
    engagement_id = fake.unique.pystr_format("E-########")
    creation_date = fake.date_between(start_date='-1y', end_date='today')
    release_date = fake.date_between(start_date=creation_date, end_date='today')
    last_time_charged_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    last_expenses_charged_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    last_active_etcp_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    engagement = fake.bs().title()
    client = fake.company()
    engagement_partner = fake.last_name() + ", " + fake.first_name()
    engagement_partner_gui = fake.unique.pystr_format("#######")
    engagement_manager = fake.last_name() + ", " + fake.first_name()
    engagement_manager_gui = fake.unique.pystr_format("#######")
    engagement_partner_service_line = random.choice(["CBS & Elim", "Assurance", "Consulting", "Tax", "SaT"])
    engagement_status = random.choice(["Released", "Active", "Pending"])

    data.append([
        engagement_id,
        creation_date,
        release_date,
        last_time_charged_date,
        last_expenses_charged_date,
        last_active_etcp_date,
        engagement,
        client,
        engagement_partner,
        engagement_partner_gui,
        engagement_manager,
        engagement_manager_gui,
        engagement_partner_service_line,
        engagement_status,
    ])

# Create a DataFrame
df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#   Engagement ID Creation Date Release Date Last Time Charged Date  \
# 0    E-19987725    2024-02-03   2024-04-27             2024-06-04
# 1    E-27700313    2023-11-07   2024-05-20             2024-06-09
# 2    E-68169104    2023-10-30   2024-01-08             2024-05-07
# 3    E-81470279    2023-09-22   2024-04-15             2024-05-30
# 4    E-91560664    2023-11-05   2024-03-30             2024-04-12
#
#   Last Expenses Charged Date Last Active ETC-P Date  \
# 0                       None             2024-05-27
# 1                       None                   None
# 2                 2024-01-16             2024-04-14
# 3                       None             2024-05-05
# 4                       None             2024-04-02
#
#                          Engagement                       Client  \
# 0         E-Enable Dynamic Eyeballs              Simpson-Manning
# 1   Seize Revolutionary Communities              Sharp-Pickering
# 2  Redefine Plug-And-Play Paradigms                 Nicholls Inc
# 3    Maximize Holistic Deliverables                  Black Group
# 4     Incentivize Proactive Metrics  Bradshaw, Harris and Dennis
#
#   Engagement Partner Engagement Partner GUI Engagement Manager  \
# 0    Marsh, Patricia                3614038    Martin, Frances
# 1  Blackburn, Ronald                3310308      Johnson, Sean
# 2        Lynch, Tony                1187526        Mann, Carol
# 3      Knight, Molly                2503745     Smith, Shannon
# 4      Morgan, Danny                2953918    Phillips, Danny
#
#   Engagement Manager GUI Engagement Partner Service Line Engagement Status
# 0                5218975                             SaT          Released
# 1                3795710                      CBS & Elim            Active
# 2                2780849                             Tax           Pending
# 3                5705446                             Tax            Active
# 4                0693247                      CBS & Elim           Pending

# %%
# Save the DataFrame to a CSV file
df.to_excel("./dummyData/test_engagementData.xlsx", index=False)

# %%
# get list of unique values in a engagement_partner_gui and engagement_manager_gui in a single list
engagement_partner_gui = df['Engagement Partner GUI'].unique().tolist()
engagement_manager_gui = df['Engagement Manager GUI'].unique().tolist()
gui = engagement_partner_gui + engagement_manager_gui
# remove duplicates
gui = list(set(gui))
# print gui size
print(len(gui))
# add faker safe email address to each gui and move to a df
email = []
for i in gui:
    email.append(fake.safe_email())
df_email = pd.DataFrame(list(zip(gui, email)), columns=['GUI', 'Email'])
# sort by gui
df_email = df_email.sort_values(by=['GUI'])
df_email.head()
# Out:
# 2000
#           GUI                      Email
# 251   0001215  johnsonolivia@example.net
# 1720  0001527    albertbruce@example.net
# 1408  0001677        jodie28@example.net
# 1726  0008711     daleelaine@example.org
# 1420  0009146        donna53@example.net

# %%
# Save the DataFrame to a CSV file
df_email.to_excel("./dummyData/test_emailList.xlsx", index=False)

# %% [markdown]
# # Exception

# %%
# list of 10 random engagement_id, append additional columns to the list as a df. Columns are: Engagement ID, Exception Reason, Exception Reason Description, Exception Reason Category, Exception Reason Subcategory, Exception Reason Type, Exception Reason Status, Exception Reason Status Description, Exception Reason Status Category,  Exception Reason Status Type, Exception Reason Status Start Date, Exception Reason Status User, Exception Reason Status User GUI, Exception Reason Status User Email
engagement_id = df['Engagement ID'].sample(n=25).tolist()
exception_reason_category = []
exception_reason_description = []
exception_reason_status = []
exception_reason_start_date = []
exception_reason_status_user = []
exception_reason_status_user_gui = []
exception_reason_status_user_email = []

for i in engagement_id:
    exception_reason_category.append(random.choice (["Tax", "Inventment Code", "Invoice", "Other"]))
    exception_reason_description.append(fake.sentence())
    exception_reason_status.append(random.choice (["Pending EP Approval", "Pending Finance Approval", "Approved", " Finance Rejected", "EP Rejected" "Expired", "New Time"]))
    exception_reason_start_date.append(fake.date_between(start_date='-4w', end_date='today'))
    exception_reason_status_user.append(fake.last_name() + ", " + fake.first_name())
    exception_reason_status_user_gui.append(fake.unique.pystr_format("#######"))
    exception_reason_status_user_email.append(fake.safe_email())

df_exception = pd.DataFrame(list(zip(engagement_id, exception_reason_category, exception_reason_description, exception_reason_status, exception_reason_start_date, exception_reason_status_user, exception_reason_status_user_gui, exception_reason_status_user_email)), columns=['Engagement ID', 'Exception Reason Category', 'Exception Reason Description', 'Exception Reason Status', 'Exception Reason Status Start Date', 'Exception Reason Status User', 'Exception Reason Status User GUI', 'Exception Reason Status User Email'])

df_exception.head(25)
# Out:
#    Engagement ID Exception Reason Category  \
# 0     E-83615405           Inventment Code
# 1     E-71315475                   Invoice
# 2     E-65028909                     Other
# 3     E-01653935                     Other
# 4     E-27151824                       Tax
# 5     E-79494737                       Tax
# 6     E-98318991           Inventment Code
# 7     E-19172275                   Invoice
# 8     E-95166209                       Tax
# 9     E-23782535                       Tax
# 10    E-62036832                       Tax
# 11    E-32390204                       Tax
# 12    E-62022795                     Other
# 13    E-46822244                     Other
# 14    E-81470279           Inventment Code
# 15    E-25062518                     Other
# 16    E-08238326                     Other
# 17    E-76482813                       Tax
# 18    E-59765408                     Other
# 19    E-14978498           Inventment Code
# 20    E-67191607                     Other
# 21    E-11652426                   Invoice
# 22    E-06771430           Inventment Code
# 23    E-45829726                     Other
# 24    E-20532318                     Other
#
#                          Exception Reason Description  \
# 0                              Velit rerum similique.
# 1   Dolorum repellendus dolorum velit accusamus un...
# 2   Nisi repudiandae sapiente repudiandae magni fu...
# 3                                Alias et cumque vel.
# 4                               Omnis ut natus fugit.
# 5                Recusandae qui possimus consequatur.
# 6                   Occaecati at asperiores repellat.
# 7                                Ipsum cum molestias.
# 8   Alias corporis amet ex blanditiis officiis tem...
# 9       Omnis a quis temporibus beatae neque tempora.
# 10                   Laudantium quas quidem rem quae.
# 11  Tempora sint natus delectus iste repellendus p...
# 12           Labore reprehenderit eveniet aspernatur.
# 13                    Autem eligendi eius recusandae.
# 14                                 Dolore tempora id.
# 15           Debitis deserunt est corrupti atque hic.
# 16      Laboriosam perferendis rem facilis omnis aut.
# 17                       Temporibus quia veniam quas.
# 18           Optio sequi magni natus cumque expedita.
# 19            Eligendi commodi eveniet vitae nostrum.
# 20               Quisquam dolorem at eaque ea unde a.
# 21        Totam adipisci repellat quia reprehenderit.
# 22  Facilis deleniti praesentium atque porro ipsa ...
# 23                 Debitis voluptates sint ut cumque.
# 24  Impedit facere ut sequi facilis explicabo cons...
#
#      Exception Reason Status Exception Reason Status Start Date  \
# 0                   New Time                         2024-05-16
# 1                   New Time                         2024-06-06
# 2           Finance Rejected                         2024-06-05
# 3                   Approved                         2024-05-22
# 4                   Approved                         2024-05-21
# 5                   New Time                         2024-06-02
# 6        Pending EP Approval                         2024-06-09
# 7                   Approved                         2024-06-11
# 8           Finance Rejected                         2024-05-20
# 9         EP RejectedExpired                         2024-06-01
# 10          Finance Rejected                         2024-05-19
# 11        EP RejectedExpired                         2024-06-10
# 12                  New Time                         2024-06-10
# 13          Finance Rejected                         2024-05-22
# 14                  New Time                         2024-05-18
# 15                  Approved                         2024-06-05
# 16                  Approved                         2024-05-20
# 17                  Approved                         2024-05-17
# 18          Finance Rejected                         2024-05-28
# 19                  New Time                         2024-05-27
# 20  Pending Finance Approval                         2024-05-29
# 21  Pending Finance Approval                         2024-05-30
# 22          Finance Rejected                         2024-06-08
# 23  Pending Finance Approval                         2024-06-02
# 24  Pending Finance Approval                         2024-06-11
#
#    Exception Reason Status User Exception Reason Status User GUI  \
# 0               Evans, Clifford                          2764092
# 1              Higgins, Charles                          0133399
# 2                 Moss, Russell                          8500961
# 3                Mills, Douglas                          9890731
# 4             Burgess, Jennifer                          5451638
# 5               Harrison, Harry                          0916183
# 6                Atkinson, Tina                          7884645
# 7                Hughes, Nathan                          5253922
# 8                Parker, Denise                          7055026
# 9               Stephens, Jayne                          2412509
# 10                 Duffy, David                          7858994
# 11                 Rees, Norman                          2442665
# 12           O'Sullivan, Leanne                          2348950
# 13                 Jones, Colin                          1865303
# 14                 Evans, Simon                          1629074
# 15               Cook, Jennifer                          1264612
# 16              Collins, Hannah                          6864903
# 17              Taylor, Chelsea                          5267004
# 18                Clarke, Dylan                          9469028
# 19                  Akhtar, Amy                          2781495
# 20                  Fox, Joanna                          5608228
# 21               Buckley, Peter                          1855430
# 22            O'Sullivan, Aaron                          5881377
# 23                 Walsh, Kevin                          7740975
# 24            Garner, Catherine                          0287146
#
#    Exception Reason Status User Email
# 0               debracarr@example.com
# 1              bellrobert@example.org
# 2               reedterry@example.net
# 3                 lewis42@example.com
# 4          cartwrightleon@example.org
# 5         catherinejordan@example.net
# 6                   qgray@example.com
# 7               westcarly@example.com
# 8           coatescameron@example.com
# 9                 hjarvis@example.org
# 10               woodjack@example.com
# 11               jonesjoe@example.org
# 12      lorrainealexander@example.org
# 13              kthompson@example.net
# 14            palmerrobin@example.com
# 15         mcdonaldtracey@example.net
# 16           shannonnixon@example.org
# 17                  zoe71@example.org
# 18              hartlouis@example.net
# 19             staceyhall@example.net
# 20                karen77@example.net
# 21                sholmes@example.org
# 22                 karl25@example.org
# 23                 sian05@example.net
# 24                  ehowe@example.com
