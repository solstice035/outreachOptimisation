# %%
import pandas as pd
from faker import Faker
# Faker.seed(999)
import random
import os
import psycopg2
from sqlalchemy import create_engine
from datetime import datetime

# %%
# Initialize Faker
fake = Faker('en_GB')

# Define the number of rows you want to generate
num_rows = 1000

# Make dir if it does not exist
dir_name = 'dummy_data'
if not os.path.exists(f'./{dir_name}'):
    os.makedirs(f'./{dir_name}')

# %%
def get_db_connection():
    return psycopg2.connect(
        dbname=os.getenv("DB_NAME"),
        user=os.getenv("DB_USER"),
        password=os.getenv("DB_PASSWORD"),
        host=os.getenv("DB_HOST"),
        port=os.getenv("DB_PORT"),
    )
def create_table_if_not_exists(connection, table_name, schema):
    cursor = connection.cursor()
    create_table_query = f"""
    CREATE TABLE IF NOT EXISTS {table_name} ({schema});
    """
    cursor.execute(create_table_query)
    connection.commit()
    cursor.close()

def insert_data(connection, df, table_name):
    engine = create_engine(f'postgresql+psycopg2://{os.getenv("DB_USER")}:{os.getenv("DB_PASSWORD")}@{os.getenv("DB_HOST")}:{os.getenv("DB_PORT")}/{os.getenv("DB_NAME")}')
    df.to_sql(table_name, engine, if_exists='append', index=False)

def load_data_to_db(df, table_name, schema):
    connection = get_db_connection()
    try:
        create_table_if_not_exists(connection, table_name, schema)
        insert_data(connection, df, table_name)
        connection.close()
        print(f"Data loaded into the {table_name} table successfully.")
    except Exception as e:
        print(f"Error loading data into database: {str(e)}")
        connection.close()

# %% [markdown]
# # Engagement Data
#
# Generate fake engagement data

# %%
# Define the columns
columns = [
    'engagement_id', 
    'creation_date', 
    'release_date', 
    'last_time_charged_date',
    'last_expenses_charged_date', 
    'last_active_etcp_date', 
    'engagement',
    'client', 
    'engagement_region', 
    'engagement_country', 
    'engagement_type',
    'currency', 
    'engagement_partner', 
    'engagement_partner_gui',
    'engagement_manager', 
    'engagement_manager_gui', 
    'engagement_partner_service_line',
    'engagement_status'
]

# Create a list to hold the data
data = []

# Function to generate consistent engagement partner and manager
def generate_partner_manager():
    last_name = fake.last_name()
    first_name = fake.first_name()
    gui = fake.unique.pystr_format("#######")
    return f"{last_name}, {first_name}", gui

# Generate dummy data
for _ in range(num_rows):
    engagement_id = fake.unique.pystr_format("E-########")
    creation_date = fake.date_between(start_date='-1y', end_date='today')
    release_date = fake.date_between(start_date=creation_date, end_date='today')
    last_time_charged_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    last_expenses_charged_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    last_active_etcp_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    engagement = fake.bs().title()
    client = fake.company()
    engagement_region = "EMEA"
    engagement_country = fake.country()
    engagement_type = "External Project"
    currency = fake.currency_code()
    engagement_partner, engagement_partner_gui = generate_partner_manager()
    engagement_manager, engagement_manager_gui = generate_partner_manager()
    engagement_partner_service_line = random.choice(["CBS & Elim", "Assurance", "Consulting", "Tax", "SaT"])
    engagement_status = random.choice(["Released", "Active", "Pending"])

    data.append([
        engagement_id,
        creation_date,
        release_date,
        last_time_charged_date,
        last_expenses_charged_date,
        last_active_etcp_date,
        engagement,
        client,
        engagement_region,
        engagement_country,
        engagement_type,
        currency,
        engagement_partner,
        engagement_partner_gui,
        engagement_manager,
        engagement_manager_gui,
        engagement_partner_service_line,
        engagement_status
    ])

# Create a DataFrame
df_engagement = pd.DataFrame(data, columns=columns)

# Create schema for cols in the table
engagement_schema = """
    engagement_id CHAR(10),
    creation_date DATE,
    release_date DATE,
    last_time_charged_date DATE,
    last_expenses_charged_date DATE,
    last_active_etcp_date DATE,
    engagement TEXT,
    client TEXT,
    engagement_region VARCHAR(10),
    engagement_country TEXT,
    engagement_type TEXT,
    currency CHAR(3),
    engagement_partner TEXT,
    engagement_partner_gui CHAR(7),
    engagement_manager TEXT,
    engagement_manager_gui CHAR(7),
    engagement_partner_service_line TEXT,
    engagement_status VARCHAR(20)
"""

# Save the DataFrame to an Excel file
file_name = "test_engagement_data.xlsx"
df_engagement.to_excel(f"./{dir_name}/{file_name}", index=False)

# Load data to the database
# load_data_to_db(df_engagement, 'engagement_data', engagement_schema)

# Display the first few rows of the DataFrame
df_engagement.head()
# Out:
#   engagement_id creation_date release_date last_time_charged_date  \
# 0    E-23313916    2023-10-09   2024-01-09                   None
# 1    E-82652400    2023-11-15   2024-01-30                   None
# 2    E-89749027    2024-02-24   2024-04-16             2024-05-23
# 3    E-65366123    2024-01-15   2024-04-05                   None
# 4    E-31340802    2024-04-20   2024-05-06                   None
#
#   last_expenses_charged_date last_active_etcp_date  \
# 0                 2024-05-21                  None
# 1                       None            2024-04-01
# 2                 2024-05-25                  None
# 3                 2024-05-21                  None
# 4                       None                  None
#
#                           engagement            client engagement_region  \
# 0    Scale Real-Time Functionalities   Lambert-Stewart              EMEA
# 1      Generate Dot-Com Applications        King Group              EMEA
# 2           Seize Synergistic Models     Bibi and Sons              EMEA
# 3  Implement Extensible Technologies  Gregory and Sons              EMEA
# 4   Monetize Interactive Initiatives     Moore-Cameron              EMEA
#
#   engagement_country   engagement_type currency engagement_partner  \
# 0            Vanuatu  External Project      ILS      Ball, Jasmine
# 1           Djibouti  External Project      ANG         Hill, Rita
# 2            Bahrain  External Project      GGP       Kay, Jeffrey
# 3             Malawi  External Project      JPY        Page, Ellie
# 4   French Polynesia  External Project      BRL     Smith, Annette
#
#   engagement_partner_gui engagement_manager engagement_manager_gui  \
# 0                9743836      Kelly, Jordan                2732773
# 1                4200322        Ball, Shane                8297959
# 2                5808488    Doherty, Edward                4971055
# 3                4371015  Robinson, Georgia                5269173
# 4                7028266       Blake, Chloe                4760900
#
#   engagement_partner_service_line engagement_status
# 0                       Assurance          Released
# 1                      CBS & Elim           Pending
# 2                             Tax           Pending
# 3                      CBS & Elim          Released
# 4                             SaT           Pending

# %%
# get list of unique values in a engagement_partner_gui and engagement_manager_gui in a single list
engagement_partner_gui = df_engagement['engagement_partner_gui'].unique().tolist()
engagement_manager_gui = df_engagement['engagement_manager_gui'].unique().tolist()
gui = engagement_partner_gui + engagement_manager_gui
# remove duplicates
gui = list(set(gui))
# print gui size
print(len(gui))
# add faker safe email address to each gui and move to a df
email = []
for i in gui:
    email.append(fake.safe_email())
df_email = pd.DataFrame(list(zip(gui, email)), columns=['GUI', 'Email'])
# sort by gui
df_email = df_email.sort_values(by=['GUI']).reset_index(drop=True)

# Save the DataFrame to a CSV file
df_email.to_excel(f"./{dir_name}/test_emailList.xlsx", index=False)

# create schema for cols in the table
email_schema = {
    'gui': 'CHAR(7)',
    'email': 'TEXT'
}

# load_data_to_db(df_email, 'email', email_schema)

df_email.head()
# Out:
# 2000
#        GUI                       Email
# 0  0006117        woodjack@example.net
# 1  0006181   eleanorcarter@example.org
# 2  0019400   butlergillian@example.com
# 3  0027495  scottkatherine@example.com
# 4  0031624        joseph38@example.com

# %% [markdown]
# # Exception

# %%
# Sample engagement_id from df_engagement
engagement_id = df_engagement['engagement_id'].sample(n=50).tolist()

# Define columns for exception data
columns = [
    'engagement_id', 
    'exception_reason_category', 
    'exception_reason_description', 
    'exception_reason_status', 
    'exception_reason_start_date', 
    'exception_reason_status_user', 
    'exception_reason_status_user_gui', 
    'exception_reason_status_user_email'
]

# Generate exception data
data = [
    [
        eid,
        random.choice(["Tax", "Investment Code", "Invoice", "Other"]),
        fake.sentence(),
        random.choice(["Pending EP Approval", "Pending Finance Approval", "Approved", "Finance Rejected", "EP Rejected", "Expired", "New Time"]),
        fake.date_between(start_date='-4w', end_date='today'),
        f"{fake.last_name()}, {fake.first_name()}",
        fake.unique.pystr_format("#######"),
        fake.safe_email()
    ]
    for eid in engagement_id
]

# Create DataFrame
df_exception = pd.DataFrame(data, columns=columns)

# Define schema for exception data
exception_schema = {
    'engagement_id': 'CHAR(10)',
    'exception_reason_category': 'TEXT',
    'exception_reason_description': 'TEXT',
    'exception_reason_status': 'TEXT',
    'exception_reason_start_date': 'DATE',
    'exception_reason_status_user': 'TEXT',
    'exception_reason_status_user_gui': 'CHAR(7)',
    'exception_reason_status_user_email': 'TEXT'
}

# Save DataFrame to an Excel file
file_name = f"test_exception_data.xlsx"
df_exception.to_excel(f"./{dir_name}/{file_name}", index=False)

# Load data to the database (uncomment the line below when the function is available)
# load_data_to_db(df_exception, 'exception', exception_schema)

# Display the first 25 rows of the DataFrame
df_exception.head(25)
# Out:
#    engagement_id exception_reason_category  \
# 0     E-30701606                     Other
# 1     E-15619013                     Other
# 2     E-68039002                     Other
# 3     E-80808709           Investment Code
# 4     E-26371593                   Invoice
# 5     E-01692719                       Tax
# 6     E-04484186                       Tax
# 7     E-60339957                   Invoice
# 8     E-33867744           Investment Code
# 9     E-69815798                       Tax
# 10    E-38268008                   Invoice
# 11    E-61977178                   Invoice
# 12    E-05730577                   Invoice
# 13    E-95491447           Investment Code
# 14    E-48295717                   Invoice
# 15    E-73877075                     Other
# 16    E-62649274                       Tax
# 17    E-71141229                       Tax
# 18    E-27232405                     Other
# 19    E-35473302           Investment Code
# 20    E-00980987           Investment Code
# 21    E-10440935                       Tax
# 22    E-65778699                       Tax
# 23    E-27483418                       Tax
# 24    E-94214181                     Other
#
#                          exception_reason_description  \
# 0        Consequuntur laboriosam recusandae repellat.
# 1                Sapiente doloremque quae quae vitae.
# 2                           Illo ad iste praesentium.
# 3             Eveniet labore earum culpa porro ipsam.
# 4                             Nisi aperiam excepturi.
# 5            Dolore eos repudiandae dolorem nesciunt.
# 6                       Beatae nesciunt animi libero.
# 7   Dolorem possimus perferendis voluptates dolor ...
# 8           Necessitatibus expedita a deserunt vitae.
# 9   Recusandae voluptatibus quidem magnam officia ...
# 10             Explicabo reiciendis vero accusantium.
# 11                         Nesciunt laudantium velit.
# 12          Explicabo impedit repudiandae laudantium.
# 13                   Quis temporibus amet dicta nemo.
# 14                       Provident autem natus ipsum.
# 15  Exercitationem odio saepe aut sapiente a recus...
# 16               Delectus facilis quia repellat sunt.
# 17  Cupiditate tempora provident dolores ducimus v...
# 18       Illum nobis commodi aliquam eos perferendis.
# 19                      Fuga ea a incidunt occaecati.
# 20                         Perspiciatis cumque saepe.
# 21                                Est suscipit porro.
# 22                Tenetur nostrum nesciunt illum est.
# 23                             Sint nobis natus enim.
# 24       Tenetur iusto itaque placeat magnam debitis.
#
#      exception_reason_status exception_reason_start_date  \
# 0                   Approved                  2024-06-10
# 1                    Expired                  2024-05-23
# 2                   New Time                  2024-06-13
# 3                   New Time                  2024-06-07
# 4                    Expired                  2024-05-19
# 5                   Approved                  2024-06-03
# 6                   New Time                  2024-05-18
# 7           Finance Rejected                  2024-05-18
# 8           Finance Rejected                  2024-06-02
# 9        Pending EP Approval                  2024-06-10
# 10                  Approved                  2024-05-22
# 11                  New Time                  2024-05-22
# 12                  Approved                  2024-06-04
# 13                  New Time                  2024-05-29
# 14          Finance Rejected                  2024-05-22
# 15                  Approved                  2024-06-03
# 16               EP Rejected                  2024-06-06
# 17  Pending Finance Approval                  2024-06-02
# 18               EP Rejected                  2024-06-10
# 19       Pending EP Approval                  2024-05-25
# 20                  New Time                  2024-05-29
# 21                  Approved                  2024-06-09
# 22                  Approved                  2024-05-28
# 23                  Approved                  2024-06-01
# 24               EP Rejected                  2024-05-17
#
#    exception_reason_status_user exception_reason_status_user_gui  \
# 0                   Grant, Jean                          5631387
# 1             Wilson, Charlotte                          3547329
# 2                   May, Nathan                          5616800
# 3              Stevens, Carolyn                          3012337
# 4               Nicholls, Abdul                          2708402
# 5              Turnbull, Connor                          3148509
# 6               Dean, Stephanie                          1234534
# 7                  Gordon, Sara                          2612822
# 8                Matthews, Lynn                          3490129
# 9               Hussain, Marion                          8894042
# 10                Davis, Oliver                          6928876
# 11              Jones, Caroline                          0539778
# 12                Ford, Brandon                          8083998
# 13            Johnson, Michelle                          9541982
# 14               Sullivan, Owen                          5409269
# 15             Woodward, Hayley                          1708212
# 16                Hunt, Russell                          6169251
# 17                Carter, Chloe                          8949782
# 18            Robinson, Richard                          8620093
# 19                  Gill, Helen                          9218863
# 20                   Wood, Kyle                          0389706
# 21                 Ahmed, Lynda                          3677372
# 22                Cooper, Garry                          0903522
# 23               Robinson, Adam                          3129939
# 24              Morrison, Lynda                          8764105
#
#    exception_reason_status_user_email
# 0            dianepeacock@example.com
# 1           garrycharlton@example.com
# 2              mohammad35@example.net
# 3                 astokes@example.com
# 4                  tony38@example.net
# 5           maureenfoster@example.org
# 6                  ladams@example.org
# 7            alisoncooper@example.net
# 8           parsonsarthur@example.com
# 9              wyattabdul@example.com
# 10               rhiggins@example.org
# 11                  kward@example.com
# 12                qbrooks@example.net
# 13                james34@example.net
# 14                denis64@example.org
# 15              francis21@example.org
# 16             karlharris@example.com
# 17                  qford@example.org
# 18              barbara25@example.net
# 19            reecethomas@example.com
# 20          wilsonkenneth@example.org
# 21          paulachambers@example.net
# 22              daletracy@example.com
# 23                qfraser@example.com
# 24         brettsanderson@example.net

# %%
# Sample 25 unique engagement IDs
engagement_id = df_engagement['engagement_id'].sample(n=25, random_state=1).tolist()

# Create a list to hold delegate information
delegate_list = []

# Generate delegate information for each engagement ID
for eid in engagement_id:
    num_delegates = random.randint(1, 3)  # Randomly choose 1, 2, or 3 delegates
    for i in range(1, num_delegates + 1):
        delegate_name = fake.last_name() + ", " + fake.first_name()
        delegate_gui = fake.unique.pystr_format("#######")
        delegate_email = fake.safe_email()
        delegate_list.append({
            'Engagement ID': eid,
            'Delegate Number': i,
            'Delegate Name': delegate_name,
            'Delegate GUI': delegate_gui,
            'Delegate Email': delegate_email
        })

# Create a DataFrame from the delegate list
df_delegate = pd.DataFrame(delegate_list)

# Sort the DataFrame by Engagement ID and Delegate Number
df_delegate = df_delegate.sort_values(by=['Engagement ID', 'Delegate Number'])

df_delegate.reset_index(drop=True, inplace=True)

# create schema for cols in the table
delegate_schema = {
    'Engagement ID': 'CHAR(10)',
    'Delegate Number': 'INTEGER',
    'Delegate Name': 'TEXT',
    'Delegate GUI': 'CHAR(7)',
    'Delegate Email': 'TEXT'
}

# load_data_to_db(df_delegate, 'delegate', delegate_schema)

# Save the DataFrame to an Excel file
df_delegate.to_excel(f"./{dir_name}/test_delegateData.xlsx", index=False)

df_delegate.head(25)
# Out:
#    Engagement ID  Delegate Number     Delegate Name Delegate GUI  \
# 0     E-03392511                1   Fowler, Vanessa      8159458
# 1     E-03392511                2    Wilkins, Jodie      1367872
# 2     E-03392511                3     Gibson, Brett      5901112
# 3     E-09136190                1      Rose, Kirsty      6976322
# 4     E-09136190                2  Robinson, Gordon      1877488
# 5     E-16872978                1       Barber, Sam      4663082
# 6     E-16872978                2    Morrison, Jack      9913527
# 7     E-18153558                1   Hayward, Martin      5037909
# 8     E-18153558                2   Clements, Allan      0550660
# 9     E-20797940                1     Payne, Elliot      6143483
# 10    E-20797940                2     Barton, James      8216310
# 11    E-21578988                1      Booth, Robin      1207771
# 12    E-30521781                1      Hobbs, Ricky      9724712
# 13    E-32984159                1      Bond, Stacey      3754567
# 14    E-32984159                2   Bishop, Shannon      1440651
# 15    E-32984159                3    Rogers, Daniel      3789892
# 16    E-43968413                1      Akhtar, Liam      4472335
# 17    E-43968413                2    Wheeler, Bruce      3601345
# 18    E-44223676                1  Mitchell, Tracey      0680149
# 19    E-44223676                2    Mistry, Joanna      3304804
# 20    E-44223676                3     Smith, Olivia      6193665
# 21    E-52591922                1   Payne, Kathleen      0708938
# 22    E-52591922                2   Hughes, Eleanor      7520225
# 23    E-58907657                1       Murray, Zoe      3139028
# 24    E-58907657                2  Macdonald, Emily      0712943
#
#                    Delegate Email
# 0         harrisamber@example.com
# 1       mccarthybryan@example.org
# 2                hlee@example.org
# 3          patricia16@example.com
# 4            allanben@example.org
# 5             jemma97@example.org
# 6         richardwebb@example.org
# 7      dixoncharlotte@example.net
# 8             dtaylor@example.com
# 9            eileen87@example.org
# 10         clarkeross@example.com
# 11             adam49@example.net
# 12             lpotts@example.org
# 13            derek45@example.org
# 14          swilliams@example.net
# 15    stevensonamelia@example.com
# 16             june15@example.net
# 17             dean65@example.org
# 18             lheath@example.net
# 19         kellybryan@example.org
# 20        louisescott@example.com
# 21       newmanstuart@example.com
# 22  cartwrightjeffrey@example.com
# 23   cartwrightamelia@example.net
# 24        webbleonard@example.org
