# %%
import pandas as pd
from faker import Faker
# Faker.seed(999)
import random
import os

# %%
# Initialize Faker
fake = Faker('en_GB')

# Define the number of rows you want to generate
num_rows = 1000

# Define the columns
columns = [
    'Engagement ID', 
    'Creation Date', 
    'Release Date', 
    'Last Time Charged Date',
    'Last Expenses Charged Date', 
    'Last Active ETCP Date', 
    'Engagement',
    'Client', 
    'Engagement Region', 
    'Engagement Country', 
    'Engagement Type',
    'Currency', 
    'Engagement Partner', 
    'Engagement Partner GUI',
    'Engagement Manager', 
    'Engagement Manager GUI', 
    'Engagement Partner Service Line',
    'Engagement Status'
]

# %%
# Create a list to hold the data
data = []

# Generate dummy data
for _ in range(num_rows):
    engagement_id = fake.unique.pystr_format("E-########")
    creation_date = fake.date_between(start_date='-1y', end_date='today')
    release_date = fake.date_between(start_date=creation_date, end_date='today')
    last_time_charged_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    last_expenses_charged_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    last_active_etcp_date = fake.date_between(start_date=release_date, end_date='today') if random.choice([True, False]) else None
    engagement = fake.bs().title()
    client = fake.company()
    engagement_region = "EMEA"
    engagement_country = fake.country()
    engagement_type = "External Project"
    currency = fake.currency_code()
    engagement_partner = fake.last_name() + ", " + fake.first_name()
    engagement_partner_gui = fake.unique.pystr_format("#######")
    engagement_manager = fake.last_name() + ", " + fake.first_name()
    engagement_manager_gui = fake.unique.pystr_format("#######")
    engagement_partner_service_line = random.choice(["CBS & Elim", "Assurance", "Consulting", "Tax", "SaT"])
    engagement_status = random.choice(["Released", "Active", "Pending"])

    data.append([
        engagement_id,
        creation_date,
        release_date,
        last_time_charged_date,
        last_expenses_charged_date,
        last_active_etcp_date,
        engagement,
        client,
        engagement_region,
        engagement_country,
        engagement_type,
        currency,
        engagement_partner,
        engagement_partner_gui,
        engagement_manager,
        engagement_manager_gui,
        engagement_partner_service_line,
        engagement_status
    ])

# Create a DataFrame
df = pd.DataFrame(data, columns=columns)

df.head()
# Out:
#   Engagement ID Creation Date Release Date Last Time Charged Date  \
# 0    E-50420642    2023-08-18   2023-12-17             2024-05-05
# 1    E-55025136    2024-06-12   2024-06-12             2024-06-13
# 2    E-42082039    2024-04-16   2024-04-30                   None
# 3    E-92780236    2024-05-20   2024-05-25             2024-06-01
# 4    E-76827784    2024-05-27   2024-06-06             2024-06-11
#
#   Last Expenses Charged Date Last Active ETCP Date  \
# 0                 2024-03-10                  None
# 1                       None                  None
# 2                       None            2024-06-02
# 3                       None            2024-05-26
# 4                       None                  None
#
#                           Engagement                        Client  \
# 0     Revolutionize Rich Convergence                    Wright LLC
# 1   Morph Cross-Media Info-Mediaries                   Jackson Inc
# 2  Maximize Value-Added Action-Items  Macdonald, Harrison and Khan
# 3              Seize Cross-Media Roi                Hall-Middleton
# 4          Exploit Dot-Com Bandwidth     Reeves, Dixon and Hartley
#
#   Engagement Region Engagement Country   Engagement Type Currency  \
# 0              EMEA            Reunion  External Project      EGP
# 1              EMEA             Malawi  External Project      SDG
# 2              EMEA              India  External Project      MOP
# 3              EMEA             Malawi  External Project      EGP
# 4              EMEA             Mexico  External Project      XCD
#
#   Engagement Partner Engagement Partner GUI Engagement Manager  \
# 0     Wilson, Andrew                9951123         Wood, Tina
# 1     Jones, Russell                8380616        Smith, Jake
# 2    Davison, Pamela                3308654     Baker, Natasha
# 3       Rice, Callum                8064158    Johnson, Hannah
# 4     Cooper, Yvonne                0973727       Nash, Jeremy
#
#   Engagement Manager GUI Engagement Partner Service Line Engagement Status
# 0                7598024                      Consulting            Active
# 1                3348389                      Consulting          Released
# 2                8984637                       Assurance           Pending
# 3                0192335                             Tax          Released
# 4                6306486                             Tax          Released

# %%
# Make dir if it does not exist

if not os.path.exists('./dummyData'):
    os.makedirs('./dummyData')


# Save the DataFrame to a CSV file
df.to_excel("./dummyData/test_engagementData.xlsx", index=False)

# %%
# get list of unique values in a engagement_partner_gui and engagement_manager_gui in a single list
engagement_partner_gui = df['Engagement Partner GUI'].unique().tolist()
engagement_manager_gui = df['Engagement Manager GUI'].unique().tolist()
gui = engagement_partner_gui + engagement_manager_gui
# remove duplicates
gui = list(set(gui))
# print gui size
print(len(gui))
# add faker safe email address to each gui and move to a df
email = []
for i in gui:
    email.append(fake.safe_email())
df_email = pd.DataFrame(list(zip(gui, email)), columns=['GUI', 'Email'])
# sort by gui
df_email = df_email.sort_values(by=['GUI'])
df_email.head()
# Out:
# 2000
#           GUI                   Email
# 1080  0002590  charleslee@example.com
# 1385  0005512      jmoran@example.com
# 1653  0007355     faustin@example.org
# 289   0018036     brett42@example.net
# 1470  0019675   rebecca85@example.org

# %%
# Save the DataFrame to a CSV file
df_email.to_excel("./dummyData/test_emailList.xlsx", index=False)

# %% [markdown]
# # Exception

# %%
# list of random engagement_id, append additional columns to the list as a df. Columns are: Engagement ID, Exception Reason, Exception Reason Description, Exception Reason Category, Exception Reason Subcategory, Exception Reason Type, Exception Reason Status, Exception Reason Status Description, Exception Reason Status Category,  Exception Reason Status Type, Exception Reason Status Start Date, Exception Reason Status User, Exception Reason Status User GUI, Exception Reason Status User Email
engagement_id = df['Engagement ID'].sample(n=50).tolist()
exception_reason_category = []
exception_reason_description = []
exception_reason_status = []
exception_reason_start_date = []
exception_reason_status_user = []
exception_reason_status_user_gui = []
exception_reason_status_user_email = []

for i in engagement_id:
    exception_reason_category.append(random.choice (["Tax", "Inventment Code", "Invoice", "Other"]))
    exception_reason_description.append(fake.sentence())
    exception_reason_status.append(random.choice (["Pending EP Approval", "Pending Finance Approval", "Approved", " Finance Rejected", "EP Rejected" "Expired", "New Time"]))
    exception_reason_start_date.append(fake.date_between(start_date='-4w', end_date='today'))
    exception_reason_status_user.append(fake.last_name() + ", " + fake.first_name())
    exception_reason_status_user_gui.append(fake.unique.pystr_format("#######"))
    exception_reason_status_user_email.append(fake.safe_email())

df_exception = pd.DataFrame(list(zip(engagement_id, exception_reason_category, exception_reason_description, exception_reason_status, exception_reason_start_date, exception_reason_status_user, exception_reason_status_user_gui, exception_reason_status_user_email)), columns=['Engagement ID', 'Exception Reason Category', 'Exception Reason Description', 'Exception Reason Status', 'Exception Reason Status Start Date', 'Exception Reason Status User', 'Exception Reason Status User GUI', 'Exception Reason Status User Email'])

df_exception.head(25)
# Out:
#    Engagement ID Exception Reason Category  \
# 0     E-72779033                   Invoice
# 1     E-89546985                   Invoice
# 2     E-92308971           Inventment Code
# 3     E-63512465                       Tax
# 4     E-45166318                       Tax
# 5     E-97511634           Inventment Code
# 6     E-00232464                     Other
# 7     E-60169040           Inventment Code
# 8     E-60336264           Inventment Code
# 9     E-51319716           Inventment Code
# 10    E-16589427                     Other
# 11    E-58980617           Inventment Code
# 12    E-06892266           Inventment Code
# 13    E-22137689                       Tax
# 14    E-26169780           Inventment Code
# 15    E-22410695                   Invoice
# 16    E-37049689                       Tax
# 17    E-82848651           Inventment Code
# 18    E-41705742                   Invoice
# 19    E-38790462                   Invoice
# 20    E-04258011                       Tax
# 21    E-82185511                       Tax
# 22    E-48489888                       Tax
# 23    E-30492935                   Invoice
# 24    E-72766424           Inventment Code
#
#                          Exception Reason Description  \
# 0                           Dicta eaque illo aperiam.
# 1                Veniam dolor similique iure placeat.
# 2                 Neque libero neque explicabo eaque.
# 3              Impedit reprehenderit vero vitae eius.
# 4           Ipsum saepe rerum quod vitae consequatur.
# 5                        Culpa est illum id voluptas.
# 6   Voluptatibus quia voluptatibus soluta perspici...
# 7   Maiores repellendus commodi fuga similique con...
# 8   Voluptates incidunt atque ullam nobis ut volup...
# 9                           Nam natus deserunt dolor.
# 10                 Non ab at accusamus fugit commodi.
# 11                        Amet quae non inventore ab.
# 12          Ipsa maxime tempore maxime aliquid porro.
# 13                     Assumenda assumenda eveniet a.
# 14   Quod tenetur distinctio debitis nam repellendus.
# 15   Ipsum doloremque repellendus consequuntur vitae.
# 16               Quis mollitia sed excepturi nostrum.
# 17               Repellendus dignissimos dolores cum.
# 18              Asperiores commodi eum ut modi nobis.
# 19    Ratione nihil unde facilis rerum quod repellat.
# 20                     Dolor aperiam ratione commodi.
# 21          Itaque occaecati iusto aperiam ad libero.
# 22       Nulla eum iure ab numquam excepturi impedit.
# 23                   Veritatis minima eligendi dolor.
# 24      Illum necessitatibus libero alias voluptatem.
#
#      Exception Reason Status Exception Reason Status Start Date  \
# 0                   New Time                         2024-05-29
# 1        Pending EP Approval                         2024-05-20
# 2   Pending Finance Approval                         2024-05-18
# 3         EP RejectedExpired                         2024-06-08
# 4           Finance Rejected                         2024-06-02
# 5                   New Time                         2024-05-19
# 6                   Approved                         2024-05-29
# 7                   New Time                         2024-06-08
# 8        Pending EP Approval                         2024-05-23
# 9                   New Time                         2024-05-27
# 10          Finance Rejected                         2024-06-01
# 11                  Approved                         2024-05-31
# 12          Finance Rejected                         2024-06-12
# 13          Finance Rejected                         2024-05-23
# 14          Finance Rejected                         2024-06-05
# 15       Pending EP Approval                         2024-06-01
# 16  Pending Finance Approval                         2024-06-09
# 17                  New Time                         2024-05-24
# 18  Pending Finance Approval                         2024-05-26
# 19  Pending Finance Approval                         2024-06-06
# 20                  Approved                         2024-05-18
# 21                  New Time                         2024-05-27
# 22          Finance Rejected                         2024-05-20
# 23       Pending EP Approval                         2024-06-03
# 24        EP RejectedExpired                         2024-05-28
#
#    Exception Reason Status User Exception Reason Status User GUI  \
# 0                 Walsh, Hayley                          8990136
# 1                  Davey, Danny                          3754268
# 2              Barnett, Michael                          0383780
# 3                  Woods, Grace                          3162637
# 4                Morris, Stuart                          6008136
# 5                Robinson, Beth                          0606173
# 6               Macdonald, Toby                          7296100
# 7                Miah, Lawrence                          4095173
# 8                 Harris, Abdul                          7560188
# 9                  Jones, Simon                          4099534
# 10             Dobson, Patricia                          7922403
# 11           Macdonald, Cameron                          7872206
# 12              Johnston, Paige                          8557189
# 13               Gregory, Glenn                          4525541
# 14                Slater, Sally                          7201445
# 15              Robson, Eleanor                          4667979
# 16               Byrne, Maurice                          0394816
# 17            Mitchell, Dorothy                          4171284
# 18               Jenkins, Molly                          4603125
# 19                Patel, Nathan                          7222334
# 20              Williams, Carly                          4395817
# 21               Lynch, Brandon                          2155726
# 22              Brown, Lorraine                          1016975
# 23                   Gray, Jade                          8284047
# 24              Marsden, Elliot                          5475867
#
#    Exception Reason Status User Email
# 0           blakelawrence@example.com
# 1             rachaelkerr@example.net
# 2             mauricejohn@example.com
# 3                pforster@example.com
# 4             dannyholmes@example.net
# 5                djohnson@example.org
# 6              stokeslucy@example.org
# 7                  ljones@example.com
# 8               qmatthews@example.org
# 9               dmitchell@example.org
# 10                bparkes@example.org
# 11             lawrence24@example.com
# 12                ewright@example.net
# 13                  zoe98@example.net
# 14           smithmelissa@example.com
# 15                 olewis@example.org
# 16              elliott01@example.com
# 17           parsonshenry@example.org
# 18            josephine86@example.org
# 19               joelwade@example.net
# 20              anntaylor@example.org
# 21          ronaldburgess@example.org
# 22                tstorey@example.com
# 23           robertparker@example.net
# 24                  pryan@example.com

# %%
df_exception.to_excel("./dummyData/test_exceptionData.xlsx", index=False)

# %%
# Sample 25 unique engagement IDs
engagement_id = df['Engagement ID'].sample(n=25, random_state=1).tolist()

# Create a list to hold delegate information
delegate_list = []

# Generate delegate information for each engagement ID
for eid in engagement_id:
    num_delegates = random.randint(1, 3)  # Randomly choose 1, 2, or 3 delegates
    for i in range(1, num_delegates + 1):
        delegate_name = fake.last_name() + ", " + fake.first_name()
        delegate_gui = fake.unique.pystr_format("#######")
        delegate_email = fake.safe_email()
        delegate_list.append({
            'Engagement ID': eid,
            'Delegate Number': i,
            'Delegate Name': delegate_name,
            'Delegate GUI': delegate_gui,
            'Delegate Email': delegate_email
        })

# Create a DataFrame from the delegate list
df_long = pd.DataFrame(delegate_list)

# Sort the DataFrame by Engagement ID and Delegate Number
df_long = df_long.sort_values(by=['Engagement ID', 'Delegate Number'])

df_long.reset_index(drop=True, inplace=True)

df_long.head(25)
# Out:
#    Engagement ID  Delegate Number       Delegate Name Delegate GUI  \
# 0     E-06560448                1      Clayton, Paige      5503484
# 1     E-12889799                1      Taylor, Donald      5298214
# 2     E-12889799                2  Phillips, Danielle      8276723
# 3     E-26907631                1          Ellis, Guy      1255919
# 4     E-26907631                2    Fletcher, Daniel      4579913
# 5     E-27755999                1       Akhtar, Garry      2124014
# 6     E-27755999                2        Ford, Antony      9267791
# 7     E-27755999                3     Barton, Carolyn      5931594
# 8     E-29324616                1           Ali, Jill      8990806
# 9     E-29324616                2      Hunter, Marion      4595618
# 10    E-29324616                3      Taylor, Graham      7643286
# 11    E-32031686                1     Newton, Malcolm      4404600
# 12    E-34503020                1    Harvey, Michelle      4923583
# 13    E-34503020                2         Moore, Marc      9685276
# 14    E-38437105                1    Williams, Andrew      2058367
# 15    E-38437105                2     Walton, Georgia      0025326
# 16    E-39331193                1       Anderson, Amy      9451255
# 17    E-42647606                1      Harper, Thomas      3079706
# 18    E-42647606                2          Reid, Adam      5464977
# 19    E-42647606                3     Davies, Charles      7323344
# 20    E-50902700                1       Foster, Scott      6393337
# 21    E-52496704                1   Jackson, Patricia      4441187
# 22    E-52496704                2     Coleman, Joanna      1464858
# 23    E-60990056                1      Marsh, Malcolm      0075165
# 24    E-60990056                2      Jones, Gregory      8350532
#
#                  Delegate Email
# 0   griffithsdennis@example.com
# 1          elaine03@example.com
# 2      douglasdavis@example.com
# 3          joanne93@example.org
# 4          fhancock@example.com
# 5        wendybrown@example.net
# 6          robert65@example.org
# 7           abdul05@example.net
# 8            kyle55@example.org
# 9           bnewton@example.org
# 10           kdavis@example.com
# 11            ndean@example.net
# 12     simpsoncarol@example.org
# 13   janicethompson@example.org
# 14  farrellbeverley@example.net
# 15           sdavis@example.net
# 16     cheryldobson@example.org
# 17   walkerrosemary@example.org
# 18     knightalison@example.org
# 19          sally48@example.com
# 20       marcfisher@example.net
# 21   burgesswilliam@example.com
# 22      wendycurtis@example.com
# 23          cwilson@example.org
# 24         aedwards@example.com

# %%
# Save the DataFrame to an Excel file
df_long.to_excel("./dummyData/test_delegateData.xlsx", index=False)
